# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow import keras
from keras.datasets import cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

cifar_class = 7  # selects class 7 (horse) as the one to be tested
selected_indices_train = (y_train.flatten() == cifar_class)
selected_indices_test = (y_test.flatten() == cifar_class)
x_train = x_train[selected_indices_train]
y_train = y_train[selected_indices_train]
x_test = x_test[selected_indices_test]
y_test = y_test[selected_indices_test]

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], -1)  # Flatten the images
x_train = x_train.astype('float32') / 255.0     # Normalize pixel values to the range [0, 1]

x_test = x_test.reshape(x_test.shape[0], -1)  # Flatten the images
x_test = x_test.astype('float32') / 255.0     # Normalize pixel values to the range [0, 1]

# Flatten the labels
y_train = (y_train.flatten() == cifar_class).astype(int)
y_test = (y_test.flatten() == cifar_class).astype(int)

# Split the data into training and testing sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size = 0.2, test_size=0.2, random_state=13)

model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(32 * 32 * 3,), activation='sigmoid')
])
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 32/32 [==============================] - 1s 3ms/step - loss: 0.1457 - accuracy: 0.9680
# Epoch 2/5
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0204e-05 - accuracy: 1.0000
# Epoch 3/5
# 32/32 [==============================] - 0s 3ms/step - loss: 1.8115e-05 - accuracy: 1.0000
# Epoch 4/5
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7957e-05 - accuracy: 1.0000
# Epoch 5/5
# 32/32 [==============================] - 0s 3ms/step - loss: 1.7876e-05 - accuracy: 1.0000
# 32/32 [==============================] - 0s 3ms/step - loss: 9.5238e-06 - accuracy: 1.0000
# Test Accuracy: 100.00%

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.datasets import cifar10

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], -1)  # Flatten the images
x_train = x_train.astype('float32') / 255.0     # Normalize pixel values to the range [0, 1]

x_test = x_test.reshape(x_test.shape[0], -1)  # Flatten the images
x_test = x_test.astype('float32') / 255.0     # Normalize pixel values to the range [0, 1]

# Convert labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Split the data into training and testing sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Single-layer perceptron model
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(32 * 32 * 3,), activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model and record accuracy over epochs
history = model.fit(x_train, y_train, epochs=50, validation_data=(x_val, y_val))

# Plot accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Evaluate on the test set
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test Accuracy: {test_acc * 100:.2f}%')
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.9800 - accuracy: 0.3098 - val_loss: 1.8168 - val_accuracy: 0.3674
# Epoch 2/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8915 - accuracy: 0.3478 - val_loss: 1.7885 - val_accuracy: 0.3738
# Epoch 3/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8670 - accuracy: 0.3562 - val_loss: 1.8263 - val_accuracy: 0.3666
# Epoch 4/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8432 - accuracy: 0.3692 - val_loss: 1.9154 - val_accuracy: 0.3674
# Epoch 5/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.8446 - accuracy: 0.3692 - val_loss: 1.8070 - val_accuracy: 0.3705
# Epoch 6/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8220 - accuracy: 0.3762 - val_loss: 1.7926 - val_accuracy: 0.3834
# Epoch 7/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8119 - accuracy: 0.3800 - val_loss: 1.8756 - val_accuracy: 0.3561
# Epoch 8/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8074 - accuracy: 0.3835 - val_loss: 1.8657 - val_accuracy: 0.3647
# Epoch 9/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8069 - accuracy: 0.3828 - val_loss: 1.8536 - val_accuracy: 0.3648
# Epoch 10/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.8023 - accuracy: 0.3835 - val_loss: 1.8588 - val_accuracy: 0.3611
# Epoch 11/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7982 - accuracy: 0.3898 - val_loss: 1.9163 - val_accuracy: 0.3550
# Epoch 12/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7977 - accuracy: 0.3903 - val_loss: 1.9640 - val_accuracy: 0.3269
# Epoch 13/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7834 - accuracy: 0.3929 - val_loss: 1.8152 - val_accuracy: 0.3773
# Epoch 14/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7883 - accuracy: 0.3920 - val_loss: 1.9325 - val_accuracy: 0.3456
# Epoch 15/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7762 - accuracy: 0.3949 - val_loss: 1.7903 - val_accuracy: 0.3877
# Epoch 16/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7709 - accuracy: 0.3970 - val_loss: 1.8455 - val_accuracy: 0.3722
# Epoch 17/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7845 - accuracy: 0.3931 - val_loss: 1.8482 - val_accuracy: 0.3787
# Epoch 18/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7752 - accuracy: 0.3957 - val_loss: 1.8349 - val_accuracy: 0.3671
# Epoch 19/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7639 - accuracy: 0.3974 - val_loss: 1.8217 - val_accuracy: 0.3660
# Epoch 20/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7711 - accuracy: 0.3968 - val_loss: 2.0227 - val_accuracy: 0.3312
# Epoch 21/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7641 - accuracy: 0.4004 - val_loss: 1.7799 - val_accuracy: 0.3932
# Epoch 22/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7564 - accuracy: 0.4021 - val_loss: 1.8671 - val_accuracy: 0.3538
# Epoch 23/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7667 - accuracy: 0.3968 - val_loss: 1.9294 - val_accuracy: 0.3493
# Epoch 24/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7524 - accuracy: 0.4045 - val_loss: 1.8332 - val_accuracy: 0.3944
# Epoch 25/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7552 - accuracy: 0.4025 - val_loss: 1.9357 - val_accuracy: 0.3562
# Epoch 26/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7618 - accuracy: 0.4020 - val_loss: 1.9338 - val_accuracy: 0.3451
# Epoch 27/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7588 - accuracy: 0.4011 - val_loss: 1.8503 - val_accuracy: 0.3625
# Epoch 28/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7568 - accuracy: 0.4039 - val_loss: 1.8337 - val_accuracy: 0.3745
# Epoch 29/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7455 - accuracy: 0.4074 - val_loss: 1.8410 - val_accuracy: 0.3822
# Epoch 30/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7598 - accuracy: 0.4033 - val_loss: 1.8983 - val_accuracy: 0.3636
# Epoch 31/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7489 - accuracy: 0.4059 - val_loss: 1.8576 - val_accuracy: 0.3538
# Epoch 32/50
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.7315 - accuracy: 0.4109 - val_loss: 1.9885 - val_accuracy: 0.3375
# Epoch 33/50
# 1250/1250 [==============================] - 5s 4ms/step - loss: 1.7507 - accuracy: 0.4067 - val_loss: 1.7969 - val_accuracy: 0.3838
# Epoch 34/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7334 - accuracy: 0.4104 - val_loss: 1.9266 - val_accuracy: 0.3561
# Epoch 35/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7462 - accuracy: 0.4096 - val_loss: 1.8516 - val_accuracy: 0.3631
# Epoch 36/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7423 - accuracy: 0.4081 - val_loss: 1.8048 - val_accuracy: 0.3855
# Epoch 37/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7370 - accuracy: 0.4101 - val_loss: 1.8058 - val_accuracy: 0.3885
# Epoch 38/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7370 - accuracy: 0.4110 - val_loss: 1.8687 - val_accuracy: 0.3747
# Epoch 39/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7319 - accuracy: 0.4117 - val_loss: 1.8391 - val_accuracy: 0.3794
# Epoch 40/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7413 - accuracy: 0.4105 - val_loss: 1.8827 - val_accuracy: 0.3671
# Epoch 41/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7339 - accuracy: 0.4117 - val_loss: 1.8938 - val_accuracy: 0.3671
# Epoch 42/50
# 1250/1250 [==============================] - 4s 4ms/step - loss: 1.7283 - accuracy: 0.4135 - val_loss: 1.9611 - val_accuracy: 0.3394
# Epoch 43/50
# 1250/1250 [==============================] - 4s 3ms/step - loss: 1.7425 - accuracy: 0.4069 - val_loss: 1.8382 - val_accuracy: 0.3720
# Epoch 44/50
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.7322 - accuracy: 0.4128
